# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# %%
# Create a set of random latitudes and longitude combinations
lat = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform (low=-180.000, high = 180.000, size=2000)
lat_lngs = zip(lat, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#import the API key
from config import weather_api_keys

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=87043da8c21491885ebfcbe0920ebedb

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
#import the requests library
import requests

#import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | qaanaaq
# Processing Record 2 of Set 16 | kodiak
# Processing Record 3 of Set 16 | bambous virieux
# Processing Record 4 of Set 16 | atuona
# Processing Record 5 of Set 16 | mareeba
# Processing Record 6 of Set 16 | chapais
# Processing Record 7 of Set 16 | aklavik
# Processing Record 8 of Set 16 | rikitea
# Processing Record 9 of Set 16 | oktyabrskiy
# Processing Record 10 of Set 16 | hobart
# Processing Record 11 of Set 16 | port lincoln
# Processing Record 12 of Set 16 | la libertad
# Processing Record 13 of Set 16 | albany
# Processing Record 14 of Set 16 | shiyan
# Processing Record 15 of Set 16 | nortelandia
# Processing Record 16 of Set 16 | bredasdorp
# Processing Record 17 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 16 | saint-philippe
# Processing Record 19 of Set 16 | butaritari
# Processing Record 20 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 16 | vaini
# Processing Record 22 of Set 16 | cape town
# Processing Record 23 of Set 16 | tukrah
# Processing Record 24 of Set 16 | avarua
# Processing Record 25 of Set 16 | chokurdakh
# Processing Record 26 of Set 16 | sakakah
# Processing Record 27 of Set 16 | busselton
# Processing Record 28 of Set 16 | avera
# Processing Record 29 of Set 16 | ushuaia
# Processing Record 30 of Set 16 | cherskiy
# Processing Record 31 of Set 16 | yar-sale
# Processing Record 32 of Set 16 | punta arenas
# Processing Record 33 of Set 16 | bairnsdale
# Processing Record 34 of Set 16 | machala
# Processing Record 35 of Set 16 | darhan
# Processing Record 36 of Set 16 | campo verde
# Processing Record 37 of Set 16 | gobabis
# Processing Record 38 of Set 16 | maniitsoq
# Processing Record 39 of Set 16 | barrow
# Processing Record 40 of Set 16 | wheeling
# Processing Record 41 of Set 16 | tuktoyaktuk
# Processing Record 42 of Set 16 | krasnoselkup
# Processing Record 43 of Set 16 | pacific grove
# Processing Record 44 of Set 16 | weinan
# Processing Record 45 of Set 16 | thompson
# Processing Record 46 of Set 16 | scarborough
# Processing Record 47 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 16 | port alfred
# Processing Record 49 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 16 | kutum
# Processing Record 1 of Set 17 | banjar
# Processing Record 2 of Set 17 | maan
# Processing Record 3 of Set 17 | chegdomyn
# Processing Record 4 of Set 17 | sao filipe
# Processing Record 5 of Set 17 | jamestown
# Processing Record 6 of Set 17 | sherbrooke
# Processing Record 7 of Set 17 | southbridge
# Processing Record 8 of Set 17 | souillac
# Processing Record 9 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 17 | hermanus
# Processing Record 11 of Set 17 | grand-lahou
# Processing Record 12 of Set 17 | hilo
# Processing Record 13 of Set 17 | darnah
# Processing Record 14 of Set 17 | grand gaube
# Processing Record 15 of Set 17 | east london
# Processing Record 16 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 17 | lagoa
# Processing Record 18 of Set 17 | garowe
# Processing Record 19 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 17 | sorland
# Processing Record 21 of Set 17 | goderich
# Processing Record 22 of Set 17 | sambava
# Processing Record 23 of Set 17 | khatanga
# Processing Record 24 of Set 17 | bilma
# Processing Record 25 of Set 17 | mar del plata
# Processing Record 26 of Set 17 | arman
# Processing Record 27 of Set 17 | kumluca
# Processing Record 28 of Set 17 | yuzhno-kurilsk
# Processing Record 29 of Set 17 | puerto ayora
# Processing Record 30 of Set 17 | abu dhabi
# Processing Record 31 of Set 17 | padang
# Processing Record 32 of Set 17 | torbay
# Processing Record 33 of Set 17 | two rivers
# Processing Record 34 of Set 17 | casper
# Processing Record 35 of Set 17 | kapaa
# Processing Record 36 of Set 17 | bluff
# Processing Record 37 of Set 17 | sao jose da coroa grande
# Processing Record 38 of Set 17 | san vicente
# Processing Record 39 of Set 17 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 17 | vaasa
# Processing Record 41 of Set 17 | kieta
# Processing Record 42 of Set 17 | nome
# Processing Record 43 of Set 17 | katsuura
# Processing Record 44 of Set 17 | saint-joseph
# Processing Record 45 of Set 17 | port elizabeth
# Processing Record 46 of Set 17 | basco
# Processing Record 47 of Set 17 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 48 of Set 17 | dawson creek
# Processing Record 49 of Set 17 | phalaborwa
# Processing Record 50 of Set 17 | bisalpur
# Processing Record 1 of Set 18 | sungairaya
# Processing Record 2 of Set 18 | broome
# Processing Record 3 of Set 18 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 18 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 18 | peniche
# Processing Record 6 of Set 18 | ponta do sol
# Processing Record 7 of Set 18 | srednekolymsk
# Processing Record 8 of Set 18 | yining
# Processing Record 9 of Set 18 | zeya
# Processing Record 10 of Set 18 | luderitz
# Processing Record 11 of Set 18 | dembi dolo
# Processing Record 12 of Set 18 | mataura
# Processing Record 13 of Set 18 | manassas
# Processing Record 14 of Set 18 | ostrovnoy
# Processing Record 15 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 18 | ixtapa
# Processing Record 17 of Set 18 | uvat
# Processing Record 18 of Set 18 | victoria
# Processing Record 19 of Set 18 | daugavpils
# Processing Record 20 of Set 18 | maryville
# Processing Record 21 of Set 18 | kaitangata
# Processing Record 22 of Set 18 | seoul
# Processing Record 23 of Set 18 | yellowknife
# Processing Record 24 of Set 18 | blackwater
# Processing Record 25 of Set 18 | chuy
# Processing Record 26 of Set 18 | hambantota
# Processing Record 27 of Set 18 | liverpool
# Processing Record 28 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 18 | hamilton
# Processing Record 30 of Set 18 | namibe
# Processing Record 31 of Set 18 | porto calvo
# Processing Record 32 of Set 18 | mahebourg
# Processing Record 33 of Set 18 | kruisfontein
# Processing Record 34 of Set 18 | rizhao
# Processing Record 35 of Set 18 | nyzhni sirohozy
# Processing Record 36 of Set 18 | new norfolk
# Processing Record 37 of Set 18 | jardim
# Processing Record 38 of Set 18 | leningradskiy
# Processing Record 39 of Set 18 | puerto baquerizo moreno
# Processing Record 40 of Set 18 | carutapera
# Processing Record 41 of Set 18 | ilulissat
# Processing Record 42 of Set 18 | upernavik
# Processing Record 43 of Set 18 | batagay
# Processing Record 44 of Set 18 | nikolskoye
# Processing Record 45 of Set 18 | morant bay
# Processing Record 46 of Set 18 | sept-iles
# Processing Record 47 of Set 18 | vila franca do campo
# Processing Record 48 of Set 18 | sitka
# Processing Record 49 of Set 18 | monte azul
# Processing Record 50 of Set 18 | horsham
# Processing Record 1 of Set 19 | adrar
# Processing Record 2 of Set 19 | dovers
# Processing Record 3 of Set 19 | ancud
# Processing Record 4 of Set 19 | mamlyutka
# Processing Record 5 of Set 19 | kaeo
# Processing Record 6 of Set 19 | ojinaga
# Processing Record 7 of Set 19 | san quintin
# Processing Record 8 of Set 19 | pevek
# Processing Record 9 of Set 19 | porto novo
# Processing Record 10 of Set 19 | golden
# Processing Record 11 of Set 19 | kadhan
# Processing Record 12 of Set 19 | castro
# Processing Record 13 of Set 19 | flin flon
# Processing Record 14 of Set 19 | turayf
# Processing Record 15 of Set 19 | shitkino
# Processing Record 16 of Set 19 | muros
# Processing Record 17 of Set 19 | akot
# Processing Record 18 of Set 19 | bandar-e lengeh
# Processing Record 19 of Set 19 | union city
# Processing Record 20 of Set 19 | khatima
# Processing Record 21 of Set 19 | longyearbyen
# Processing Record 22 of Set 19 | port-de-bouc
# Processing Record 23 of Set 19 | severo-kurilsk
# Processing Record 24 of Set 19 | mehamn
# Processing Record 25 of Set 19 | carnarvon
# Processing Record 26 of Set 19 | ostroveni
# Processing Record 27 of Set 19 | klaksvik
# Processing Record 28 of Set 19 | arraial do cabo
# Processing Record 29 of Set 19 | rio brilhante
# Processing Record 30 of Set 19 | lebu
# Processing Record 31 of Set 19 | narsaq
# Processing Record 32 of Set 19 | nalut
# Processing Record 33 of Set 19 | olafsvik
# Processing Record 34 of Set 19 | bud
# Processing Record 35 of Set 19 | sao joao da barra
# Processing Record 36 of Set 19 | jonkoping
# Processing Record 37 of Set 19 | kursk
# Processing Record 38 of Set 19 | prainha
# Processing Record 39 of Set 19 | dikson
# Processing Record 40 of Set 19 | caucaia
# Processing Record 41 of Set 19 | te anau
# Processing Record 42 of Set 19 | aldan
# Processing Record 43 of Set 19 | prince rupert
# Processing Record 44 of Set 19 | shenjiamen
# Processing Record 45 of Set 19 | lompoc
# Processing Record 46 of Set 19 | saskylakh
# Processing Record 47 of Set 19 | vanimo
# Processing Record 48 of Set 19 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 19 | faanui
# Processing Record 50 of Set 19 | alofi
# Processing Record 1 of Set 20 | cabo san lucas
# Processing Record 2 of Set 20 | angoche
# Processing Record 3 of Set 20 | nuuk
# Processing Record 4 of Set 20 | cidreira
# Processing Record 5 of Set 20 | turan
# Processing Record 6 of Set 20 | linxia
# Processing Record 7 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 20 | tuatapere
# Processing Record 9 of Set 20 | chinna salem
# Processing Record 10 of Set 20 | parrita
# Processing Record 11 of Set 20 | korla
# Processing Record 12 of Set 20 | requena
# Processing Record 13 of Set 20 | aykhal
# Processing Record 14 of Set 20 | cockburn town
# Processing Record 15 of Set 20 | sudak
# Processing Record 16 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 20 | rassvet
# Processing Record 18 of Set 20 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 20 | presidencia roque saenz pena
# Processing Record 20 of Set 20 | jodhpur
# Processing Record 21 of Set 20 | marawi
# Processing Record 22 of Set 20 | hasaki
# Processing Record 23 of Set 20 | opobo
# City not found. Skipping...
# Processing Record 24 of Set 20 | biak
# Processing Record 25 of Set 20 | warrington
# Processing Record 26 of Set 20 | hithadhoo
# Processing Record 27 of Set 20 | mattru
# Processing Record 28 of Set 20 | georgetown
# Processing Record 29 of Set 20 | awbari
# Processing Record 30 of Set 20 | praia da vitoria
# Processing Record 31 of Set 20 | hobe sound
# Processing Record 32 of Set 20 | homer
# Processing Record 33 of Set 20 | kloulklubed
# Processing Record 34 of Set 20 | kavieng
# Processing Record 35 of Set 20 | miri
# Processing Record 36 of Set 20 | villa maria
# Processing Record 37 of Set 20 | tambura
# Processing Record 38 of Set 20 | burica
# City not found. Skipping...
# Processing Record 39 of Set 20 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 20 | sooke
# Processing Record 41 of Set 20 | madimba
# Processing Record 42 of Set 20 | kokologo
# Processing Record 43 of Set 20 | zhigansk
# Processing Record 44 of Set 20 | pisco
# Processing Record 45 of Set 20 | la ronge
# Processing Record 46 of Set 20 | mandalgovi
# Processing Record 47 of Set 20 | sistranda
# Processing Record 48 of Set 20 | howard springs
# Processing Record 49 of Set 20 | cherkasskoye
# Processing Record 50 of Set 20 | mayo
# Processing Record 1 of Set 21 | komsomolskiy
# Processing Record 2 of Set 21 | swan hill
# Processing Record 3 of Set 21 | lorengau
# Processing Record 4 of Set 21 | catalina
# Processing Record 5 of Set 21 | nizwa
# Processing Record 6 of Set 21 | iqaluit
# Processing Record 7 of Set 21 | kinablangan
# Processing Record 8 of Set 21 | high level
# Processing Record 9 of Set 21 | kalengwa
# Processing Record 10 of Set 21 | vasylivka
# Processing Record 11 of Set 21 | ribeira grande
# Processing Record 12 of Set 21 | changping
# Processing Record 13 of Set 21 | askino
# Processing Record 14 of Set 21 | hovd
# Processing Record 15 of Set 21 | coquimbo
# Processing Record 16 of Set 21 | abha
# Processing Record 17 of Set 21 | la roche-sur-yon
# Processing Record 18 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 21 | sibolga
# Processing Record 20 of Set 21 | airai
# Processing Record 21 of Set 21 | blonduos
# City not found. Skipping...
# Processing Record 22 of Set 21 | barcelos
# Processing Record 23 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 21 | coihueco
# Processing Record 25 of Set 21 | maraba
# Processing Record 26 of Set 21 | clyde river
# Processing Record 27 of Set 21 | griffith
# Processing Record 28 of Set 21 | shakawe
# Processing Record 29 of Set 21 | santa maria
# Processing Record 30 of Set 21 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 21 | lagunas
# Processing Record 32 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 21 | boyolangu
# Processing Record 34 of Set 21 | quang ngai
# Processing Record 35 of Set 21 | nanortalik
# Processing Record 36 of Set 21 | hasilpur
# Processing Record 37 of Set 21 | meulaboh
# Processing Record 38 of Set 21 | oksbol
# Processing Record 39 of Set 21 | alyangula
# Processing Record 40 of Set 21 | taiyuan
# Processing Record 41 of Set 21 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 21 | devonport
# Processing Record 43 of Set 21 | norman wells
# Processing Record 44 of Set 21 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 21 | jumla
# Processing Record 46 of Set 21 | souris
# Processing Record 47 of Set 21 | poya
# Processing Record 48 of Set 21 | yulara
# Processing Record 49 of Set 21 | esperance
# Processing Record 50 of Set 21 | tiarei
# Processing Record 1 of Set 22 | hanmer springs
# Processing Record 2 of Set 22 | bubaque
# Processing Record 3 of Set 22 | bengkulu
# Processing Record 4 of Set 22 | clarksburg
# Processing Record 5 of Set 22 | mansa
# Processing Record 6 of Set 22 | la asuncion
# Processing Record 7 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 22 | charala
# Processing Record 9 of Set 22 | shamary
# Processing Record 10 of Set 22 | honiara
# Processing Record 11 of Set 22 | margate
# Processing Record 12 of Set 22 | sisimiut
# Processing Record 13 of Set 22 | illela
# Processing Record 14 of Set 22 | impfondo
# Processing Record 15 of Set 22 | erenhot
# Processing Record 16 of Set 22 | guerrero negro
# Processing Record 17 of Set 22 | santa marinella
# Processing Record 18 of Set 22 | shingu
# Processing Record 19 of Set 22 | nelson bay
# Processing Record 20 of Set 22 | makakilo city
# Processing Record 21 of Set 22 | mega
# Processing Record 22 of Set 22 | ningan
# City not found. Skipping...
# Processing Record 23 of Set 22 | half moon bay
# Processing Record 24 of Set 22 | faya
# Processing Record 25 of Set 22 | bardiyah
# Processing Record 26 of Set 22 | ginir
# Processing Record 27 of Set 22 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 22 | atar
# Processing Record 29 of Set 22 | lengshuitan
# Processing Record 30 of Set 22 | yanam
# Processing Record 31 of Set 22 | antsohihy
# Processing Record 32 of Set 22 | cluses
# Processing Record 33 of Set 22 | santo augusto
# Processing Record 34 of Set 22 | hirson
# Processing Record 35 of Set 22 | saint-pierre
# Processing Record 36 of Set 22 | tasiilaq
# Processing Record 37 of Set 22 | puerto pinasco
# City not found. Skipping...
# Processing Record 38 of Set 22 | bandarbeyla
# Processing Record 39 of Set 22 | bilibino
# Processing Record 40 of Set 22 | yingcheng
# Processing Record 41 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 22 | chapada dos guimaraes
# Processing Record 43 of Set 22 | kununurra
# Processing Record 44 of Set 22 | preston
# Processing Record 45 of Set 22 | elko
# Processing Record 46 of Set 22 | kinshasa
# Processing Record 47 of Set 22 | fayaoue
# Processing Record 48 of Set 22 | bendigo
# Processing Record 49 of Set 22 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 22 | concordia
# Processing Record 1 of Set 23 | ulcinj
# Processing Record 2 of Set 23 | gimli
# Processing Record 3 of Set 23 | marsabit
# Processing Record 4 of Set 23 | arrecife
# Processing Record 5 of Set 23 | huilong
# Processing Record 6 of Set 23 | plettenberg bay
# Processing Record 7 of Set 23 | dagana
# Processing Record 8 of Set 23 | talnakh
# Processing Record 9 of Set 23 | kamennogorsk
# Processing Record 10 of Set 23 | yongan
# Processing Record 11 of Set 23 | sao gabriel da cachoeira
# Processing Record 12 of Set 23 | maragogipe
# Processing Record 13 of Set 23 | rota
# Processing Record 14 of Set 23 | lakatoro
# Processing Record 15 of Set 23 | pierre
# Processing Record 16 of Set 23 | dekar
# Processing Record 17 of Set 23 | sawtell
# Processing Record 18 of Set 23 | kwinana
# Processing Record 19 of Set 23 | kamina
# Processing Record 20 of Set 23 | port blair
# Processing Record 21 of Set 23 | xuddur
# Processing Record 22 of Set 23 | geraldton
# Processing Record 23 of Set 23 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 23 | husavik
# Processing Record 25 of Set 23 | birnin kebbi
# Processing Record 26 of Set 23 | udachnyy
# Processing Record 27 of Set 23 | laguna
# Processing Record 28 of Set 23 | lubbecke
# Processing Record 29 of Set 23 | codrington
# Processing Record 30 of Set 23 | kitimat
# Processing Record 31 of Set 23 | kosa
# Processing Record 32 of Set 23 | sivaki
# Processing Record 33 of Set 23 | mackay
# Processing Record 34 of Set 23 | karacakoy
# Processing Record 35 of Set 23 | salalah
# Processing Record 36 of Set 23 | san juan
# Processing Record 37 of Set 23 | luxor
# Processing Record 38 of Set 23 | tongliao
# Processing Record 39 of Set 23 | oum hadjer
# Processing Record 40 of Set 23 | cururupu
# Processing Record 41 of Set 23 | grimari
# City not found. Skipping...
# Processing Record 42 of Set 23 | san policarpo
# Processing Record 43 of Set 23 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 23 | leshukonskoye
# Processing Record 45 of Set 23 | westport
# Processing Record 46 of Set 23 | lasa
# Processing Record 47 of Set 23 | vidim
# Processing Record 48 of Set 23 | staroaleyskoye
# Processing Record 49 of Set 23 | manta
# Processing Record 50 of Set 23 | hami
# Processing Record 1 of Set 24 | herat
# Processing Record 2 of Set 24 | kahului
# Processing Record 3 of Set 24 | lazaro cardenas
# Processing Record 4 of Set 24 | alice springs
# Processing Record 5 of Set 24 | touros
# Processing Record 6 of Set 24 | karasburg
# Processing Record 7 of Set 24 | vestmannaeyjar
# Processing Record 8 of Set 24 | devgarh
# Processing Record 9 of Set 24 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 24 | ketchikan
# Processing Record 11 of Set 24 | santa pola
# Processing Record 12 of Set 24 | khor
# Processing Record 13 of Set 24 | luanda
# Processing Record 14 of Set 24 | kyren
# Processing Record 15 of Set 24 | yumen
# Processing Record 16 of Set 24 | kangaatsiaq
# Processing Record 17 of Set 24 | dolinsk
# Processing Record 18 of Set 24 | guamuchil
# Processing Record 19 of Set 24 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 24 | tamandare
# Processing Record 21 of Set 24 | saldanha
# Processing Record 22 of Set 24 | sao francisco de paula
# Processing Record 23 of Set 24 | college
# Processing Record 24 of Set 24 | kyzyl-suu
# Processing Record 25 of Set 24 | saint george
# Processing Record 26 of Set 24 | pianco
# Processing Record 27 of Set 24 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 24 | port hedland
# Processing Record 29 of Set 24 | mishelevka
# Processing Record 30 of Set 24 | ahipara
# Processing Record 31 of Set 24 | durban
# Processing Record 32 of Set 24 | aksu
# Processing Record 33 of Set 24 | jinja
# Processing Record 34 of Set 24 | hervey bay
# Processing Record 35 of Set 24 | toba
# Processing Record 36 of Set 24 | saint-leu
# Processing Record 37 of Set 24 | hobyo
# Processing Record 38 of Set 24 | agva
# City not found. Skipping...
# Processing Record 39 of Set 24 | agde
# Processing Record 40 of Set 24 | maracas
# Processing Record 41 of Set 24 | flinders
# Processing Record 42 of Set 24 | anori
# Processing Record 43 of Set 24 | la rioja
# Processing Record 44 of Set 24 | bethel
# Processing Record 45 of Set 24 | mahon
# Processing Record 46 of Set 24 | great yarmouth
# Processing Record 47 of Set 24 | athens
# Processing Record 48 of Set 24 | spanish town
# Processing Record 49 of Set 24 | mae sai
# Processing Record 50 of Set 24 | sola
# Processing Record 1 of Set 25 | sioux lookout
# Processing Record 2 of Set 25 | port-gentil
# Processing Record 3 of Set 25 | kalabo
# Processing Record 4 of Set 25 | brae
# Processing Record 5 of Set 25 | adana
# Processing Record 6 of Set 25 | lomza
# Processing Record 7 of Set 25 | fukue
# Processing Record 8 of Set 25 | teya
# Processing Record 9 of Set 25 | moron
# Processing Record 10 of Set 25 | taoudenni
# Processing Record 11 of Set 25 | yatou
# Processing Record 12 of Set 25 | imeni poliny osipenko
# Processing Record 13 of Set 25 | nordfjordeid
# Processing Record 14 of Set 25 | katsina
# Processing Record 15 of Set 25 | vakhrushev
# Processing Record 16 of Set 25 | machali
# Processing Record 17 of Set 25 | anshun
# Processing Record 18 of Set 25 | general bravo
# Processing Record 19 of Set 25 | namatanai
# Processing Record 20 of Set 25 | maua
# Processing Record 21 of Set 25 | richards bay
# Processing Record 22 of Set 25 | lusambo
# Processing Record 23 of Set 25 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 25 | yerofey pavlovich
# Processing Record 25 of Set 25 | praya
# Processing Record 26 of Set 25 | sal rei
# Processing Record 27 of Set 25 | gat
# Processing Record 28 of Set 25 | tiksi
# Processing Record 29 of Set 25 | issoire
# Processing Record 30 of Set 25 | ardakan
# Processing Record 31 of Set 25 | aranda de duero
# Processing Record 32 of Set 25 | berdychiv
# Processing Record 33 of Set 25 | stephenville
# Processing Record 34 of Set 25 | singaraja
# Processing Record 35 of Set 25 | batang berjuntai
# Processing Record 36 of Set 25 | tautira
# Processing Record 37 of Set 25 | saint-michel-des-saints
# Processing Record 38 of Set 25 | maumere
# Processing Record 39 of Set 25 | polyarnyy
# Processing Record 40 of Set 25 | chikwawa
# Processing Record 41 of Set 25 | khislavichi
# Processing Record 42 of Set 25 | biloela
# Processing Record 43 of Set 25 | havelock
# Processing Record 44 of Set 25 | camabatela
# Processing Record 45 of Set 25 | constitucion
# Processing Record 46 of Set 25 | portland
# Processing Record 47 of Set 25 | nueva loja
# Processing Record 48 of Set 25 | gerash
# Processing Record 49 of Set 25 | dunedin
# Processing Record 50 of Set 25 | privokzalnyy
# City not found. Skipping...
# Processing Record 1 of Set 26 | galle
# Processing Record 2 of Set 26 | bathsheba
# Processing Record 3 of Set 26 | nicoya
# Processing Record 4 of Set 26 | burdur
# Processing Record 5 of Set 26 | lata
# Processing Record 6 of Set 26 | tiznit
# Processing Record 7 of Set 26 | ugoofaaru
# Processing Record 8 of Set 26 | chivilcoy
# Processing Record 9 of Set 26 | mweka
# Processing Record 10 of Set 26 | berezhany
# Processing Record 11 of Set 26 | itoman
# Processing Record 12 of Set 26 | inta
# Processing Record 13 of Set 26 | yichun
# Processing Record 14 of Set 26 | konin
# Processing Record 15 of Set 26 | goirle
# Processing Record 16 of Set 26 | hwange
# Processing Record 17 of Set 26 | egvekinot
# Processing Record 18 of Set 26 | mildura
# Processing Record 19 of Set 26 | oktyabrskoye
# Processing Record 20 of Set 26 | fuerte olimpo
# Processing Record 21 of Set 26 | vestmanna
# Processing Record 22 of Set 26 | ngunguru
# Processing Record 23 of Set 26 | paamiut
# Processing Record 24 of Set 26 | kupang
# Processing Record 25 of Set 26 | port macquarie
# Processing Record 26 of Set 26 | jalingo
# Processing Record 27 of Set 26 | kamenka
# Processing Record 28 of Set 26 | sulphur
# Processing Record 29 of Set 26 | nabire
# Processing Record 30 of Set 26 | qaqortoq
# Processing Record 31 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 26 | mariestad
# Processing Record 33 of Set 26 | wuwei
# Processing Record 34 of Set 26 | deputatskiy
# Processing Record 35 of Set 26 | rawson
# Processing Record 36 of Set 26 | vardo
# Processing Record 37 of Set 26 | sungaipenuh
# Processing Record 38 of Set 26 | takoradi
# Processing Record 39 of Set 26 | kamloops
# Processing Record 40 of Set 26 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 26 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 26 | vila
# Processing Record 43 of Set 26 | ciudad bolivar
# Processing Record 44 of Set 26 | kaka
# Processing Record 45 of Set 26 | provideniya
# Processing Record 46 of Set 26 | mocuba
# Processing Record 47 of Set 26 | tura
# Processing Record 48 of Set 26 | ponta delgada
# Processing Record 49 of Set 26 | blacksburg
# Processing Record 50 of Set 26 | talah
# City not found. Skipping...
# Processing Record 1 of Set 27 | grindavik
# Processing Record 2 of Set 27 | caravelas
# Processing Record 3 of Set 27 | shumskiy
# Processing Record 4 of Set 27 | ibra
# Processing Record 5 of Set 27 | mogadishu
# Processing Record 6 of Set 27 | meadow lake
# Processing Record 7 of Set 27 | cap-aux-meules
# Processing Record 8 of Set 27 | seymchan
# Processing Record 9 of Set 27 | san patricio
# Processing Record 10 of Set 27 | alekseyevsk
# Processing Record 11 of Set 27 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 27 | quatre cocos
# Processing Record 13 of Set 27 | selfoss
# Processing Record 14 of Set 27 | lac-au-saumon
# Processing Record 15 of Set 27 | sechura
# Processing Record 16 of Set 27 | esqueda
# Processing Record 17 of Set 27 | clyde
# Processing Record 18 of Set 27 | oyama
# Processing Record 19 of Set 27 | abbeville
# Processing Record 20 of Set 27 | albanel
# Processing Record 21 of Set 27 | berbera
# Processing Record 22 of Set 27 | aguining
# Processing Record 23 of Set 27 | brawley
# Processing Record 24 of Set 27 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 27 | pitimbu
# Processing Record 26 of Set 27 | nantucket
# Processing Record 27 of Set 27 | robertsport
# Processing Record 28 of Set 27 | shahrud
# Processing Record 29 of Set 27 | wucheng
# Processing Record 30 of Set 27 | najran
# Processing Record 31 of Set 27 | ust-nera
# Processing Record 32 of Set 27 | port hardy
# Processing Record 33 of Set 27 | moultonborough
# Processing Record 34 of Set 27 | tenenkou
# Processing Record 35 of Set 27 | cayenne
# Processing Record 36 of Set 27 | pospelikha
# Processing Record 37 of Set 27 | villa constitucion
# Processing Record 38 of Set 27 | antofagasta
# Processing Record 39 of Set 27 | kerema
# Processing Record 40 of Set 27 | gaya
# Processing Record 41 of Set 27 | dodge city
# Processing Record 42 of Set 27 | borogontsy
# Processing Record 43 of Set 27 | saint-francois
# Processing Record 44 of Set 27 | nahrin
# Processing Record 45 of Set 27 | isabela
# Processing Record 46 of Set 27 | mungwi
# Processing Record 47 of Set 27 | nador
# Processing Record 48 of Set 27 | jalu
# Processing Record 49 of Set 27 | san jose
# Processing Record 50 of Set 27 | kopanskaya
# Processing Record 1 of Set 28 | andenes
# Processing Record 2 of Set 28 | keti bandar
# Processing Record 3 of Set 28 | borger
# Processing Record 4 of Set 28 | leo
# Processing Record 5 of Set 28 | lavrentiya
# Processing Record 6 of Set 28 | jacareacanga
# Processing Record 7 of Set 28 | labuan
# Processing Record 8 of Set 28 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 28 | tonj
# Processing Record 10 of Set 28 | kharp
# Processing Record 11 of Set 28 | karratha
# Processing Record 12 of Set 28 | am timan
# Processing Record 13 of Set 28 | beringovskiy
# Processing Record 14 of Set 28 | myra
# Processing Record 15 of Set 28 | eirunepe
# Processing Record 16 of Set 28 | broken hill
# Processing Record 17 of Set 28 | las choapas
# Processing Record 18 of Set 28 | bemidji
# Processing Record 19 of Set 28 | liminangcong
# City not found. Skipping...
# Processing Record 20 of Set 28 | berlevag
# Processing Record 21 of Set 28 | byron bay
# Processing Record 22 of Set 28 | sorong
# Processing Record 23 of Set 28 | vao
# Processing Record 24 of Set 28 | okha
# Processing Record 25 of Set 28 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 28 | daru
# Processing Record 27 of Set 28 | malartic
# Processing Record 28 of Set 28 | duz
# City not found. Skipping...
# Processing Record 29 of Set 28 | snasa
# Processing Record 30 of Set 28 | santa rosa
# Processing Record 31 of Set 28 | ambilobe
# Processing Record 32 of Set 28 | rio grande
# Processing Record 33 of Set 28 | mount gambier
# Processing Record 34 of Set 28 | lohja
# Processing Record 35 of Set 28 | minab
# Processing Record 36 of Set 28 | nyimba
# Processing Record 37 of Set 28 | aasiaat
# Processing Record 38 of Set 28 | opuwo
# Processing Record 39 of Set 28 | strzelce krajenskie
# Processing Record 40 of Set 28 | kuusamo
# Processing Record 41 of Set 28 | araouane
# Processing Record 42 of Set 28 | kabanjahe
# Processing Record 43 of Set 28 | karakol
# Processing Record 44 of Set 28 | luba
# Processing Record 45 of Set 28 | hualmay
# Processing Record 46 of Set 28 | medicine hat
# Processing Record 47 of Set 28 | trairi
# Processing Record 48 of Set 28 | viedma
# Processing Record 49 of Set 28 | belyy yar
# Processing Record 50 of Set 28 | bend
# Processing Record 1 of Set 29 | pithapuram
# Processing Record 2 of Set 29 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 29 | parabel
# Processing Record 4 of Set 29 | tarata
# Processing Record 5 of Set 29 | eureka
# Processing Record 6 of Set 29 | bitung
# Processing Record 7 of Set 29 | tocantins
# Processing Record 8 of Set 29 | ranong
# Processing Record 9 of Set 29 | christiana
# Processing Record 10 of Set 29 | buin
# Processing Record 11 of Set 29 | rio gallegos
# Processing Record 12 of Set 29 | beoumi
# Processing Record 13 of Set 29 | rapid valley
# Processing Record 14 of Set 29 | ranipur
# Processing Record 15 of Set 29 | evensk
# Processing Record 16 of Set 29 | asau
# Processing Record 17 of Set 29 | preobrazheniye
# Processing Record 18 of Set 29 | khormuj
# City not found. Skipping...
# Processing Record 19 of Set 29 | reconquista
# Processing Record 20 of Set 29 | karla
# Processing Record 21 of Set 29 | kropotkin
# Processing Record 22 of Set 29 | denham springs
# Processing Record 23 of Set 29 | tazmalt
# Processing Record 24 of Set 29 | qalyub
# Processing Record 25 of Set 29 | fort nelson
# Processing Record 26 of Set 29 | gravdal
# Processing Record 27 of Set 29 | vegueta
# Processing Record 28 of Set 29 | mandali
# Processing Record 29 of Set 29 | verkhnyaya inta
# Processing Record 30 of Set 29 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 29 | kushima
# Processing Record 32 of Set 29 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 29 | abu zabad
# Processing Record 34 of Set 29 | fairbanks
# Processing Record 35 of Set 29 | tilichiki
# Processing Record 36 of Set 29 | lofthus
# Processing Record 37 of Set 29 | kitangari
# Processing Record 38 of Set 29 | kisanga
# Processing Record 39 of Set 29 | sur
# Processing Record 40 of Set 29 | nishihara
# Processing Record 41 of Set 29 | namie
# Processing Record 42 of Set 29 | storforshei
# Processing Record 43 of Set 29 | dafeng
# Processing Record 44 of Set 29 | cabra
# Processing Record 45 of Set 29 | kostyantynivka
# Processing Record 46 of Set 29 | havre-saint-pierre
# Processing Record 47 of Set 29 | campeche
# Processing Record 48 of Set 29 | dauphin
# Processing Record 49 of Set 29 | keetmanshoop
# Processing Record 50 of Set 29 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 30 | roma
# Processing Record 2 of Set 30 | alta floresta
# Processing Record 3 of Set 30 | languyan
# Processing Record 4 of Set 30 | mukhtolovo
# Processing Record 5 of Set 30 | copiapo
# Processing Record 6 of Set 30 | puerto ayacucho
# Processing Record 7 of Set 30 | pangkalanbuun
# Processing Record 8 of Set 30 | mnisek pod brdy
# Processing Record 9 of Set 30 | coos bay
# Processing Record 10 of Set 30 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 30 | nakamura
# Processing Record 12 of Set 30 | chiang rai
# Processing Record 13 of Set 30 | vaitape
# Processing Record 14 of Set 30 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 30 | tekeli
# Processing Record 16 of Set 30 | dannenberg
# Processing Record 17 of Set 30 | anadyr
# Processing Record 18 of Set 30 | ankang
# Processing Record 19 of Set 30 | xining
# Processing Record 20 of Set 30 | onda
# Processing Record 21 of Set 30 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 30 | kusu
# Processing Record 23 of Set 30 | eydhafushi
# Processing Record 24 of Set 30 | uyskoye
# Processing Record 25 of Set 30 | neiafu
# Processing Record 26 of Set 30 | general roca
# Processing Record 27 of Set 30 | parasia
# Processing Record 28 of Set 30 | pyapon
# Processing Record 29 of Set 30 | garden city
# Processing Record 30 of Set 30 | olinda
# Processing Record 31 of Set 30 | yabelo
# Processing Record 32 of Set 30 | miraflores
# Processing Record 33 of Set 30 | aktau
# Processing Record 34 of Set 30 | black diamond
# Processing Record 35 of Set 30 | gitarama
# Processing Record 36 of Set 30 | glenwood springs
# Processing Record 37 of Set 30 | lundazi
# Processing Record 38 of Set 30 | san cristobal
# Processing Record 39 of Set 30 | cap malheureux
# Processing Record 40 of Set 30 | eyl
# Processing Record 41 of Set 30 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 30 | esso
# Processing Record 43 of Set 30 | karakose
# City not found. Skipping...
# Processing Record 44 of Set 30 | tadine
# Processing Record 45 of Set 30 | jinotega
# Processing Record 46 of Set 30 | nandikotkur
# Processing Record 47 of Set 30 | the valley
# Processing Record 48 of Set 30 | dawei
# Processing Record 49 of Set 30 | hay river
# Processing Record 50 of Set 30 | umm lajj
# Processing Record 1 of Set 31 | smithers
# Processing Record 2 of Set 31 | talara
# Processing Record 3 of Set 31 | ucluelet
# Processing Record 4 of Set 31 | nanma
# Processing Record 5 of Set 31 | noumea
# Processing Record 6 of Set 31 | pochutla
# Processing Record 7 of Set 31 | warsaw
# Processing Record 8 of Set 31 | novikovo
# Processing Record 9 of Set 31 | price
# Processing Record 10 of Set 31 | dingle
# Processing Record 11 of Set 31 | puro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Qaanaaq  77.4840  -69.3632     18.68        82          11
# 1           Kodiak  57.7900 -152.4072     39.97        84           8
# 2  Bambous Virieux -20.3428   57.7575     74.21        70          52
# 3           Atuona  -9.8000 -139.0333     77.07        76          73
# 4          Mareeba -17.0000  145.4333     68.72        95          65
# 5          Chapais  49.7834  -74.8492     44.38        97         100
# 6          Aklavik  68.2191 -135.0107     27.75        77          98
# 7          Rikitea -23.1203 -134.9692     72.03        74          91
# 8      Oktyabrskiy  54.4815   53.4710     43.25        48          94
# 9           Hobart -42.8794  147.3294     50.05        81          90
#
#    Wind Speed Country                 Date Current Description
# 0        4.70      GL  2021-09-29 14:10:52          few clouds
# 1        7.45      US  2021-09-29 14:10:52           clear sky
# 2       13.38      MU  2021-09-29 14:06:24       broken clouds
# 3       20.76      PF  2021-09-29 14:05:54          light rain
# 4        3.47      AU  2021-09-29 14:07:58       broken clouds
# 5        4.50      CA  2021-09-29 14:10:53     overcast clouds
# 6       11.41      CA  2021-09-29 14:10:53     overcast clouds
# 7       16.58      PF  2021-09-29 14:10:54          light rain
# 8        7.16      RU  2021-09-29 14:10:54     overcast clouds
# 9        5.75      AU  2021-09-29 14:10:54     overcast clouds

# %%
new_column_order = ['City', "Country", "Date", 'Lat', 'Lng', "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Qaanaaq      GL  2021-09-29 14:10:52  77.4840  -69.3632     18.68
# 1           Kodiak      US  2021-09-29 14:10:52  57.7900 -152.4072     39.97
# 2  Bambous Virieux      MU  2021-09-29 14:06:24 -20.3428   57.7575     74.21
# 3           Atuona      PF  2021-09-29 14:05:54  -9.8000 -139.0333     77.07
# 4          Mareeba      AU  2021-09-29 14:07:58 -17.0000  145.4333     68.72
# 5          Chapais      CA  2021-09-29 14:10:53  49.7834  -74.8492     44.38
# 6          Aklavik      CA  2021-09-29 14:10:53  68.2191 -135.0107     27.75
# 7          Rikitea      PF  2021-09-29 14:10:54 -23.1203 -134.9692     72.03
# 8      Oktyabrskiy      RU  2021-09-29 14:10:54  54.4815   53.4710     43.25
# 9           Hobart      AU  2021-09-29 14:10:54 -42.8794  147.3294     50.05
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        82          11        4.70          few clouds
# 1        84           8        7.45           clear sky
# 2        70          52       13.38       broken clouds
# 3        76          73       20.76          light rain
# 4        95          65        3.47       broken clouds
# 5        97         100        4.50     overcast clouds
# 6        77          98       11.41     overcast clouds
# 7        74          91       16.58          light rain
# 8        48          94        7.16     overcast clouds
# 9        81          90        5.75     overcast clouds

# %%
#Create the output file (CSV)
output_data_file = 'Weather_Database/Weather_Database.csv'

#export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
